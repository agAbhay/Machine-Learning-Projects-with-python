# %%
import pandas as pd

# %%
bunny=pd.read_csv(r"C:\Users\Abhay Gupta\Downloads\Compressed\DataSets-master\DataSets-master\Advertising.csv")

# %%
bunny
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
bunny.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
bunny.shape
# Out:
# (200, 5)

# %%
x_input=bunny.iloc[:,1:4]

# %%
x_input
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# 5      8.7   48.9       75.0
# 6     57.5   32.8       23.5
# 7    120.2   19.6       11.6
# 8      8.6    2.1        1.0
# 9    199.8    2.6       21.2
# 10    66.1    5.8       24.2
# 11   214.7   24.0        4.0
# 12    23.8   35.1       65.9
# 13    97.5    7.6        7.2
# 14   204.1   32.9       46.0
# 15   195.4   47.7       52.9
# 16    67.8   36.6      114.0
# 17   281.4   39.6       55.8
# 18    69.2   20.5       18.3
# 19   147.3   23.9       19.1
# 20   218.4   27.7       53.4
# 21   237.4    5.1       23.5
# 22    13.2   15.9       49.6
# 23   228.3   16.9       26.2
# 24    62.3   12.6       18.3
# 25   262.9    3.5       19.5
# 26   142.9   29.3       12.6
# 27   240.1   16.7       22.9
# 28   248.8   27.1       22.9
# 29    70.6   16.0       40.8
# ..     ...    ...        ...
# ...

# %%
#second way to do that 
X_input=bunny.loc[:,"TV":"newspaper"]

# %%
X_input
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# 5      8.7   48.9       75.0
# 6     57.5   32.8       23.5
# 7    120.2   19.6       11.6
# 8      8.6    2.1        1.0
# 9    199.8    2.6       21.2
# 10    66.1    5.8       24.2
# 11   214.7   24.0        4.0
# 12    23.8   35.1       65.9
# 13    97.5    7.6        7.2
# 14   204.1   32.9       46.0
# 15   195.4   47.7       52.9
# 16    67.8   36.6      114.0
# 17   281.4   39.6       55.8
# 18    69.2   20.5       18.3
# 19   147.3   23.9       19.1
# 20   218.4   27.7       53.4
# 21   237.4    5.1       23.5
# 22    13.2   15.9       49.6
# 23   228.3   16.9       26.2
# 24    62.3   12.6       18.3
# 25   262.9    3.5       19.5
# 26   142.9   29.3       12.6
# 27   240.1   16.7       22.9
# 28   248.8   27.1       22.9
# 29    70.6   16.0       40.8
# ..     ...    ...        ...
# ...

# %%
Y_out=bunny.iloc[:,4]

# %%
Xarr=X_input.values.reshape(200,3)

# %%
Yarr=Y_out.values.reshape(200,1)

# %%
#split
x_train=Xarr[:140]
x_test=Xarr[140:]
y_train=Yarr[:140]
y_test=Yarr[140:]

# %%
from sklearn.linear_model import LinearRegression

# %%
teacher=LinearRegression()

# %%
learner=teacher.fit(x_train,y_train)

# %%
#prediction
yp=learner.predict(x_test)
yplist=list(yp)

# %%
ya=y_test

xlist=list(x_test)
yalist=list(y_test)
mytable=pd.DataFrame({"ya":yalist,"yp":yplist})

# %%
mytable
# Out:
#         ya               yp
# 0   [10.9]  [9.51435440217]
# 1   [19.2]  [18.2920287655]
# 2   [20.1]  [19.2709406424]
# 3   [10.4]  [8.88723581838]
# 4   [11.4]  [10.1136170553]
# 5   [10.3]   [9.9604197209]
# 6   [13.2]  [15.6270678766]
# 7   [25.4]  [23.1587013047]
# 8   [10.9]  [12.0384503076]
# 9   [10.1]  [9.72212471318]
# 10  [16.1]  [18.6380945508]
# 11  [11.6]  [10.1009986722]
# 12  [16.6]  [16.4858961557]
# 13  [19.0]  [18.1246860868]
# 14  [15.6]  [15.6436426643]
# 15   [3.2]  [5.30523275025]
# 16  [15.3]   [15.127442315]
# 17  [10.1]  [10.2535872485]
# 18   [7.3]    [10.09006252]
# 19  [12.9]  [12.4436279147]
# 20  [14.4]  [14.3210308997]
# 21  [13.3]  [13.3616907959]
# 22  [14.9]   [15.084433307]
# 23  [18.0]  [17.3276943328]
# 24  [11.9]  [11.1843574864]
# 25  [11.9]  [14.4341080988]
# 26   [8.0]   [10.578473771]
# 27  [12.2]  [13.6508529813]
# 28  [17.1]  [17.2468260432]
# 29  [15.0]  [18.3064862321]
# 30   [8.4]  [7.42659652251]
# 31  [14.5]  [14.3975608839]
# ...

# %%
#error
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
error=np.sqrt(mean_squared_error(ya,yp))

# %%
error
# Out:
# 1.5993642253910214

# %%
slope=learner.coef_

# %%
slope
# Out:
# array([[ 0.04704868,  0.17968299, -0.00300557]])

# %%
m1=slope[0,0]
m2=slope[0,1]
m3=slope[0,2]

# %%
slope[0,1]
# Out:
# 0.17968298889993567

# %%
slope[0,0]
# Out:
# 0.047048680822289274

# %%
learner.intercept_
# Out:
# array([ 3.04514221])

# %%
tv=x_test[:,0]

# %%
tv
# Out:
# array([  73.4,  193.7,  220.5,  104.6,   96.2,  140.3,  240.1,  243.2,
#          38. ,   44.7,  280.7,  121. ,  197.6,  171.3,  187.8,    4.1,
#          93.9,  149.8,   11.7,  131.7,  172.5,   85.7,  188.4,  163.5,
#         117.2,  234.5,   17.9,  206.8,  215.4,  284.3,   50. ,  164.5,
#          19.6,  168.4,  222.4,  276.9,  248.4,  170.2,  276.7,  165.6,
#         156.6,  218.5,   56.2,  287.6,  253.8,  205. ,  139.5,  191.1,
#         286. ,   18.7,   39.5,   75.5,   17.2,  166.8,  149.7,   38.2,
#          94.2,  177. ,  283.6,  232.1])

# %%
r=x_test[0:1]

# %%
news=x_test[0:2]

# %%
c=3.045

# %%
x_test_tv=x_test[:,0]
x_test_r=x_test[:,1]
x_test_news=x_test[:,2]

# %%
yptv =x_test_tv*m1+c

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(x_test_tv,yptv,"ro")
plt.plot(x_test_tv,y_test,"b>")
plt.legend(["yptv","yp"])
plt.show()

# %%
news=x_test_news*m2+c

# %%
news
# Out:
# array([  5.36291056,  16.62903396,   9.85498528,   9.22609482,
#         10.03466827,   4.6621469 ,   4.608242  ,  11.00495641,
#          5.18322757,   6.74646957,   9.69327059,  11.79556156,
#          5.59649844,   9.81904868,   4.75198839,   4.06919304,
#         12.11899094,   7.41129663,  11.1666711 ,   9.26203142,
#          8.56126776,  11.90337135,   7.64488452,   4.37465412,
#          4.01528814,  18.28211746,   6.92615256,   6.53084998,
#         13.39474016,   4.19497113,   6.351167  ,  11.56197367,
#          6.09961081,   5.34494226,   5.39884715,  10.55574894,
#          6.69256467,   9.36984121,   7.30348684,   6.2074206 ,
#          4.53636881,   7.9683139 ,   8.38158477,  15.9462386 ,
#          8.43548967,   6.56678658,   7.8245675 ,   6.3152304 ,
#          3.70982706,   7.24958194,   4.08716134,   4.12309793,
#          8.72298245,   3.69185876,   4.12309793,   5.52462525,
#          4.50043221,   4.19497113,  14.94001387,   4.608242  ])

# %%
plt.plot(x_test_news,news,"ro")
plt.plot(x_test_news,y_test,"b>")
plt.legend(["news","yp"])
plt.show()

# %%
learner.predict([[45,40,69]])
# Out:
# array([[ 12.14226841]])

# %%
radio=x_test_news*m3+c

# %%
plt.plot(x_test_r,radio,"ro")
plt.plot(x_test_r,y_test,"b>")
plt.legend(["radio","yp"])
plt.show()
