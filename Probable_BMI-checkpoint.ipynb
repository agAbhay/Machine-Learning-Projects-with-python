# %%
import pandas as kg

# %%
import numpy as np

# %%
bunny=kg.read_csv(r"C:\Users\STUDENT\Desktop\SonalkgML\DataSets-master\bmi_male_female.csv")

# %%
X_GHW=bunny.iloc[:,0:4]

# %%
Y_index=bunny.iloc[:,3]

# %%
X_GHW
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# 5      Male     189     104      3
# 6      Male     147      92      5
# 7      Male     154     111      5
# 8      Male     174      90      3
# 9    Female     169     103      4
# 10     Male     195      81      2
# 11   Female     159      80      4
# 12   Female     192     101      3
# 13     Male     155      51      2
# 14     Male     191      79      2
# 15   Female     153     107      5
# 16   Female     157     110      5
# 17     Male     140     129      5
# 18     Male     144     145      5
# 19     Male     172     139      5
# 20     Male     157     110      5
# 21   Female     153     149      5
# 22   Female     169      97      4
# 23     Male     185     139      5
# 24   Female     172      67      2
# 25   Female     151      64      3
# ...

# %%
Y_index
# Out:
# 0      4
# 1      2
# 2      4
# 3      3
# 4      3
# 5      3
# 6      5
# 7      5
# 8      3
# 9      4
# 10     2
# 11     4
# 12     3
# 13     2
# 14     2
# 15     5
# 16     5
# 17     5
# 18     5
# 19     5
# 20     5
# 21     5
# 22     4
# 23     5
# 24     2
# 25     3
# 26     3
# 27     1
# 28     5
# 29     5
#       ..
# 470    5
# 471    5
# 472    2
# 473    5
# 474    3
# 475    4
# 476    5
# 477    2
# 478    2
# 479    5
# 480    5
# 481    4
# 482    5
# 483    4
# 484    4
# 485    4
# 486    5
# 487    2
# 488    4
# 489    5
# 490    2
# 491    5
# 492    0
# 493    1
# 494    5
# 495    5
# 496    4
# 497    5
# 498    5
# 499    5
# Name: Index, dtype: int64

# %%
X_GHW.Gender[X_GHW.Gender=="Male"]=0
X_GHW.Gender[X_GHW.Gender=="Female"]=1
# Out:
# C:\Users\STUDENT\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\STUDENT\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
X_GHW
# Out:
#     Gender  Height  Weight  Index
# 0        0     174      96      4
# 1        0     189      87      2
# 2        1     185     110      4
# 3        1     195     104      3
# 4        0     149      61      3
# 5        0     189     104      3
# 6        0     147      92      5
# 7        0     154     111      5
# 8        0     174      90      3
# 9        1     169     103      4
# 10       0     195      81      2
# 11       1     159      80      4
# 12       1     192     101      3
# 13       0     155      51      2
# 14       0     191      79      2
# 15       1     153     107      5
# 16       1     157     110      5
# 17       0     140     129      5
# 18       0     144     145      5
# 19       0     172     139      5
# 20       0     157     110      5
# 21       1     153     149      5
# 22       1     169      97      4
# 23       0     185     139      5
# 24       1     172      67      2
# 25       1     151      64      3
# ...

# %%
#reshape
X_Input=X_GHW.values.reshape(len(X_GHW),3)
Y_output=Y_index.values.reshape(len(Y_index),1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f8cc2edd67dc> in <module>()
#       1 #reshape
# ----> 2 X_Input=X_GHW.values.reshape(len(X_GHW),3)
#       3 Y_output=Y_index.values.reshape(len(Y_index),1)
#
# NameError: name 'X_GHW' is not defined
