# %%
import pandas as kg

# %%
bunny=kg.read_csv(r"C:\Users\STUDENT\Desktop\SonalkgML\DataSets-master\DataSets-master\Car_sales.csv")

# %%
bunny
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# 5    Audi           A6                             18.780              23.555
# 6    Audi           A8                              1.380                  39
# 7    BMW            323i                           19.747                   .
# 8    BMW            328i                            9.231              28.675
# 9    BMW            528i                           17.527              36.125
# 10   Buick          Century                        91.561              12.475
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
myle=LabelEncoder()

# %%
bunny.iloc[:,0]=myle.fit_transform(bunny.iloc[:,0])

# %%
bunny
# Out:
#      Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0               0  Integra                        16.919               16.36
# 1               0  TL                             39.384              19.875
# 2               0  CL                             14.114              18.225
# 3               0  RL                              8.588              29.725
# 4               1  A4                             20.397              22.255
# 5               1  A6                             18.780              23.555
# 6               1  A8                              1.380                  39
# 7               2  323i                           19.747                   .
# 8               2  328i                            9.231              28.675
# 9               2  528i                           17.527              36.125
# 10              3  Century                        91.561              12.475
# ...
