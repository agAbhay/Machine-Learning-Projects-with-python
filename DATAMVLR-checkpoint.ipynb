# %%
import pandas as kg

# %%
bunny=kg.read_csv(r"C:\Users\STUDENT\Desktop\SonalkgML\DataSets-master\Data_MVLR.csv")

# %%
bunny
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
X_input=bunny.iloc[:,0:4]

# %%
X_input
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
Y_output=bunny.iloc[:,4]

# %%
Y_output
# Out:
# 0     541
# 1     524
# 2     561
# 3     414
# 4     410
# 5     457
# 6     344
# 7     467
# 8     464
# 9     498
# 10    580
# 11    471
# 12    525
# 13    508
# 14    566
# 15    635
# 16    603
# 17    714
# 18    865
# 19    640
# 20    649
# 21    540
# 22    464
# 23    547
# 24    460
# 25    566
# 26    577
# 27    631
# 28    574
# 29    534
# 30    571
# 31    554
# 32    577
# 33    628
# 34    487
# 35    644
# 36    640
# 37    704
# 38    648
# 39    968
# 40    587
# 41    699
# 42    632
# 43    591
# 44    782
# 45    510
# 46    610
# 47    524
# Name: Petrol_Consumption, dtype: int64

# %%
xx_input=X_input.values.reshape(-1,4)
yy_output=Y_output.values.reshape(-1,1)

# %%
xx_input
# Out:
# array([[  9.00000000e+00,   3.57100000e+03,   1.97600000e+03,
#           5.25000000e-01],
#        [  9.00000000e+00,   4.09200000e+03,   1.25000000e+03,
#           5.72000000e-01],
#        [  9.00000000e+00,   3.86500000e+03,   1.58600000e+03,
#           5.80000000e-01],
#        [  7.50000000e+00,   4.87000000e+03,   2.35100000e+03,
#           5.29000000e-01],
#        [  8.00000000e+00,   4.39900000e+03,   4.31000000e+02,
#           5.44000000e-01],
#        [  1.00000000e+01,   5.34200000e+03,   1.33300000e+03,
#           5.71000000e-01],
#        [  8.00000000e+00,   5.31900000e+03,   1.18680000e+04,
#           4.51000000e-01],
#        [  8.00000000e+00,   5.12600000e+03,   2.13800000e+03,
#           5.53000000e-01],
#        [  8.00000000e+00,   4.44700000e+03,   8.57700000e+03,
#           5.29000000e-01],
#        [  7.00000000e+00,   4.51200000e+03,   8.50700000e+03,
#           5.52000000e-01],
#        [  8.00000000e+00,   4.39100000e+03,   5.93900000e+03,
# ...

# %%
X_train=xx_input[:34]
X_test=xx_input[34:]
Y_train=yy_output[:34]
Y_test=yy_output[34:]

# %%
from sklearn.linear_model import LinearRegression

# %%
teacher=LinearRegression()

# %%
learner=teacher.fit(X_train,Y_train)
yp=learner.predict(X_test)

# %%
learner.intercept_
# Out:
# array([ 213.75100223])

# %%
learner.coef_
# Out:
# array([[ -1.19748946e+01,  -7.37055373e-02,   3.16773588e-03,
#           1.29987409e+03]])

# %%
ya=Y_test
yplist=list(yp)
xlist=list(X_test)
yalist=list(Y_test)
mytable=kg.DataFrame({"X_test":xlist,"ya":yalist,"yp":yplist})

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
error=np.sqrt(mean_squared_error(ya,yp))

# %%
error
# Out:
# 95.452729096861034

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
myscaler=MinMaxScaler()

# %%
XX_train=X_train
XX_test=X_test

# %%
Xtrain_afterscaling=myscaler.fit_transform(XX_train)
Xtest_afterscaling=myscaler.fit_transform(XX_test)

# %%
teacher=LinearRegression()

# %%
learner=teacher.fit(Xtrain_afterscaling,Y_train)
yp=learner.predict(Xtest_afterscaling)

# %%
ya=Y_test
yplist=list(yp)
xlist=list(X_test)
yalist=list(Y_test)
mytable=kg.DataFrame({"X_test":xlist,"ya":yalist,"yp":yplist})

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
error1=np.sqrt(mean_squared_error(ya,yp))

# %%
error1
# Out:
# 92.143980555221944
