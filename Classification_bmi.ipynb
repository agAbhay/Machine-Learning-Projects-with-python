# %%
import pandas as pd

# %%
bunny=pd.read_csv(r"C:\Users\Abhay Gupta\Downloads\Compressed\DataSets-master\DataSets-master\bmi.csv")

# %%
bunny
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# 5      Male     189     104      3
# 6      Male     147      92      5
# 7      Male     154     111      5
# 8      Male     174      90      3
# 9    Female     169     103      4
# 10     Male     195      81      2
# 11   Female     159      80      4
# 12   Female     192     101      3
# 13     Male     155      51      2
# 14     Male     191      79      2
# 15   Female     153     107      5
# 16   Female     157     110      5
# 17     Male     140     129      5
# 18     Male     144     145      5
# 19     Male     172     139      5
# 20     Male     157     110      5
# 21   Female     153     149      5
# 22   Female     169      97      4
# 23     Male     185     139      5
# 24   Female     172      67      2
# 25   Female     151      64      3
# ...

# %%
bunny.head(1)
# Out:
#   Gender  Height  Weight  Index
# 0   Male     174      96      4

# %%
bunny.shape
# Out:
# (500, 4)

# %%
male=bunny[bunny["Gender"]=="Male"]

# %%
len(male)
# Out:
# 245

# %%
noofmaleow=male[male["Index"]==3]

# %%
noofmaleow
# Out:
#     Gender  Height  Weight  Index
# 4     Male     149      61      3
# 5     Male     189     104      3
# 8     Male     174      90      3
# 26    Male     190      95      3
# 48    Male     161      72      3
# 80    Male     164      75      3
# 109   Male     149      66      3
# 115   Male     148      60      3
# 137   Male     194     108      3
# 146   Male     194     106      3
# 148   Male     195      98      3
# 151   Male     140      52      3
# 162   Male     192     101      3
# 179   Male     188     100      3
# 185   Male     165      80      3
# 201   Male     179      93      3
# 208   Male     191      96      3
# 226   Male     166      70      3
# 235   Male     170      81      3
# 240   Male     178      85      3
# 246   Male     182      98      3
# 250   Male     153      70      3
# 274   Male     178      83      3
# 278   Male     172      75      3
# 291   Male     183     105      3
# 316   Male     188      99      3
# ...

# %%
noofmaleow.shape
# Out:
# (32, 4)

# %%
female=bunny[bunny["Gender"]=="Female"]

# %%
female
# Out:
#      Gender  Height  Weight  Index
# 2    Female     185     110      4
# 3    Female     195     104      3
# 9    Female     169     103      4
# 11   Female     159      80      4
# 12   Female     192     101      3
# 15   Female     153     107      5
# 16   Female     157     110      5
# 21   Female     153     149      5
# 22   Female     169      97      4
# 24   Female     172      67      2
# 25   Female     151      64      3
# 28   Female     163     159      5
# 32   Female     195      65      1
# 33   Female     160     131      5
# 34   Female     157     153      5
# 35   Female     189     132      4
# 36   Female     197     114      3
# 38   Female     171     152      5
# 39   Female     185      81      2
# 40   Female     175     120      4
# 41   Female     149     108      5
# 44   Female     182     126      4
# 46   Female     188     122      4
# 50   Female     168     135      5
# 51   Female     176      54      1
# 55   Female     187      89      3
# ...

# %%
nooffemaleow=female[female["Index"]==3]

# %%
nooffemaleow
# Out:
#      Gender  Height  Weight  Index
# 3    Female     195     104      3
# 12   Female     192     101      3
# 25   Female     151      64      3
# 36   Female     197     114      3
# 55   Female     187      89      3
# 58   Female     164      70      3
# 74   Female     185     100      3
# 82   Female     190     105      3
# 91   Female     183      96      3
# 92   Female     194     111      3
# 149  Female     168     115      3
# 152  Female     150      60      3
# 156  Female     182      84      3
# 158  Female     187     102      3
# 168  Female     151      67      3
# 177  Female     181      94      3
# 180  Female     162      74      3
# 184  Female     192     108      3
# 187  Female     182      84      3
# 232  Female     184      86      3
# 233  Female     177      81      3
# 248  Female     188      90      3
# 275  Female     187      94      3
# 292  Female     162      68      3
# 298  Female     187      92      3
# 328  Female     164      71      3
# ...

# %%
len(nooffemaleow)
# Out:
# 36

# %%
index_name=pd.Series(["Extremely Weak","Weak","Normal","Overweight","Obesity","Extreme Obesity"])

# %%
index_name[4]
# Out:
# 'Obesity'

# %%
index_name
# Out:
# 0     Extremely Weak
# 1               Weak
# 2             Normal
# 3         Overweight
# 4            Obesity
# 5    Extreme Obesity
# dtype: object

# %%
#Encode Male......0,Female......1
bunny.Gender[bunny.Gender=="Male"]=0
bunny.Gender[bunny.Gender=="Female"]=1
# Out:
# C:\Users\Abhay Gupta\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\Abhay Gupta\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
bunny
# Out:
#     Gender  Height  Weight  Index
# 0        0     174      96      4
# 1        0     189      87      2
# 2        1     185     110      4
# 3        1     195     104      3
# 4        0     149      61      3
# 5        0     189     104      3
# 6        0     147      92      5
# 7        0     154     111      5
# 8        0     174      90      3
# 9        1     169     103      4
# 10       0     195      81      2
# 11       1     159      80      4
# 12       1     192     101      3
# 13       0     155      51      2
# 14       0     191      79      2
# 15       1     153     107      5
# 16       1     157     110      5
# 17       0     140     129      5
# 18       0     144     145      5
# 19       0     172     139      5
# 20       0     157     110      5
# 21       1     153     149      5
# 22       1     169      97      4
# 23       0     185     139      5
# 24       1     172      67      2
# 25       1     151      64      3
# ...

# %%
x_input=bunny.drop("Index",axis=1)
#x_input=bunny.iloc[:,0:3]
#x_input=bunny[["Gender","Height","Weight"]]
#x_input=bunny.loc[:,"Gender":"Weight"]

# %%
x_input
# Out:
#     Gender  Height  Weight
# 0        0     174      96
# 1        0     189      87
# 2        1     185     110
# 3        1     195     104
# 4        0     149      61
# 5        0     189     104
# 6        0     147      92
# 7        0     154     111
# 8        0     174      90
# 9        1     169     103
# 10       0     195      81
# 11       1     159      80
# 12       1     192     101
# 13       0     155      51
# 14       0     191      79
# 15       1     153     107
# 16       1     157     110
# 17       0     140     129
# 18       0     144     145
# 19       0     172     139
# 20       0     157     110
# 21       1     153     149
# 22       1     169      97
# 23       0     185     139
# 24       1     172      67
# 25       1     151      64
# 26       0     190      95
# 27       0     187      62
# 28       1     163     159
# 29       0     179     152
# ..     ...     ...     ...
# 470      0     147     142
# 471      0     154     112
# ...

# %%
#y_out=bunny["Index"]
y_out=bunny.iloc[:,3]

# %%
y_out
# Out:
# 0      4
# 1      2
# 2      4
# 3      3
# 4      3
# 5      3
# 6      5
# 7      5
# 8      3
# 9      4
# 10     2
# 11     4
# 12     3
# 13     2
# 14     2
# 15     5
# 16     5
# 17     5
# 18     5
# 19     5
# 20     5
# 21     5
# 22     4
# 23     5
# 24     2
# 25     3
# 26     3
# 27     1
# 28     5
# 29     5
#       ..
# 470    5
# 471    5
# 472    2
# 473    5
# 474    3
# 475    4
# 476    5
# 477    2
# 478    2
# 479    5
# 480    5
# 481    4
# 482    5
# 483    4
# 484    4
# 485    4
# 486    5
# 487    2
# 488    4
# 489    5
# 490    2
# 491    5
# 492    0
# 493    1
# 494    5
# 495    5
# 496    4
# 497    5
# 498    5
# 499    5
# Name: Index, dtype: int64

# %%
x_input.shape
# Out:
# (500, 3)

# %%
y_out
# Out:
# 0      4
# 1      2
# 2      4
# 3      3
# 4      3
# 5      3
# 6      5
# 7      5
# 8      3
# 9      4
# 10     2
# 11     4
# 12     3
# 13     2
# 14     2
# 15     5
# 16     5
# 17     5
# 18     5
# 19     5
# 20     5
# 21     5
# 22     4
# 23     5
# 24     2
# 25     3
# 26     3
# 27     1
# 28     5
# 29     5
#       ..
# 470    5
# 471    5
# 472    2
# 473    5
# 474    3
# 475    4
# 476    5
# 477    2
# 478    2
# 479    5
# 480    5
# 481    4
# 482    5
# 483    4
# 484    4
# 485    4
# 486    5
# 487    2
# 488    4
# 489    5
# 490    2
# 491    5
# 492    0
# 493    1
# 494    5
# 495    5
# 496    4
# 497    5
# 498    5
# 499    5
# Name: Index, dtype: int64

# %%
y_out.shape
# Out:
# (500,)

# %%
import numpy as np

# %%
X=np.array(x_input)

# %%
type(x_input)
# Out:
# pandas.core.frame.DataFrame

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X=x_input.values.reshape(500,3)

# %%
X
# Out:
# array([[0, 174, 96],
#        [0, 189, 87],
#        [1, 185, 110],
#        ...,
#        [1, 141, 136],
#        [0, 150, 95],
#        [0, 173, 131]], dtype=object)

# %%
X=x_input.values.reshape(1,-1)

# %%
X
# Out:
# array([[0, 174, 96, ..., 0, 173, 131]], dtype=object)

# %%
X.shape
# Out:
# (1, 1500)

# %%
X_GHW=x_input.values.reshape(500,3)

# %%
X
# Out:
# array([[0, 174, 96],
#        [0, 189, 87],
#        [1, 185, 110],
#        ...,
#        [1, 141, 136],
#        [0, 150, 95],
#        [0, 173, 131]], dtype=object)

# %%
Y_I=y_out.values.reshape(500,1)

# %%
Y.shape
# Out:
# (500, 1)

# %%
#splitting the data into train and test set
X_train=X_GHW[:350]
X_test=X_GHW[350:]
Y_train=Y_I[:350]
Y_test=Y_I[350:]

# %%
Y_train.shape
# Out:
# (350, 1)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
teacher= KNeighborsClassifier()

# %%
learner=teacher.fit(X_train,Y_train)
# Out:
# C:\Users\Abhay Gupta\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   if __name__ == '__main__':

# %%
p=learner.predict([[0,170,69]])
index_name[p]
# Out:
# 2    Normal
# dtype: object

# %%
#testing
#X_test[150x3]......Y_test[1501x1]
Ya=Y_test
Yp=learner.predict(X_test)

# %%
Yalist=list(Ya)
Yplist=list(Yp)

# %%
table=pd.DataFrame({"Ya":Yalist,"Yp":Yplist})

# %%
table
# Out:
#       Ya  Yp
# 0    [2]   3
# 1    [2]   2
# 2    [2]   2
# 3    [5]   5
# 4    [0]   0
# 5    [3]   3
# 6    [4]   4
# 7    [5]   5
# 8    [1]   1
# 9    [4]   5
# 10   [1]   1
# 11   [4]   5
# 12   [5]   5
# 13   [4]   4
# 14   [5]   5
# 15   [5]   4
# 16   [3]   3
# 17   [4]   4
# 18   [5]   5
# 19   [4]   4
# 20   [3]   3
# 21   [5]   5
# 22   [1]   1
# 23   [2]   2
# 24   [4]   4
# 25   [5]   5
# 26   [5]   5
# 27   [5]   5
# 28   [5]   4
# 29   [3]   3
# ..   ...  ..
# 120  [5]   5
# 121  [5]   5
# 122  [2]   2
# 123  [5]   4
# 124  [3]   3
# 125  [4]   4
# 126  [5]   5
# 127  [2]   2
# 128  [2]   2
# 129  [5]   5
# 130  [5]   5
# 131  [4]   4
# 132  [5]   5
# 133  [4]   5
# 134  [4]   4
# 135  [4]   4
# 136  [5]   5
# 137  [2]   2
# 138  [4]   4
# 139  [5]   5
# 140  [2]   2
# 141  [5]   5
# 142  [0]   0
# 143  [1]   2
# 144  [5]   5
# 145  [5]   5
# 146  [4]   4
# 147  [5]   5
# 148  [5]   5
# 149  [5]   5
#
# [150 rows x 2 columns]

# %%
table.head(2)
# Out:
#     Ya  Yp
# 0  [2]   3
# 1  [2]   2

# %%
from sklearn.metrics import accuracy_score

# %%
acc=accuracy_score(Ya,Yp)*100

# %%
acc
# Out:
# 91.333333333333329
