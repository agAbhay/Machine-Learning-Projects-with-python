# %%
import pandas as pd

# %%
bunny=pd.read_csv(r"C:\Users\Abhay Gupta\ad_csv(r"C:\Users\Abhay Gupta\Downloads\Compressed\DataSets-master\DataSets-master\Titanic_Data.csv")

# %%
bunny
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
bunny.loc[:,["Pclass","Name"]]
# Out:
#      Pclass                                               Name
# 0         3                            Braund, Mr. Owen Harris
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         3                             Heikkinen, Miss. Laina
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         3                           Allen, Mr. William Henry
# 5         3                                   Moran, Mr. James
# 6         1                            McCarthy, Mr. Timothy J
# 7         3                     Palsson, Master. Gosta Leonard
# 8         3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         2                Nasser, Mrs. Nicholas (Adele Achem)
# 10        3                    Sandstrom, Miss. Marguerite Rut
# 11        1                           Bonnell, Miss. Elizabeth
# 12        3                     Saundercock, Mr. William Henry
# 13        3                        Andersson, Mr. Anders Johan
# ...

# %%
bunny.loc[:,"Pclass":"Age"]
# Out:
#      Pclass                                               Name     Sex   Age
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# 5         3                                   Moran, Mr. James    male   NaN
# 6         1                            McCarthy, Mr. Timothy J    male  54.0
# 7         3                     Palsson, Master. Gosta Leonard    male   2.0
# 8         3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9         2                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10        3                    Sandstrom, Miss. Marguerite Rut  female   4.0
# ...

# %%
bunny.loc[:,"Pclass":"Age"]
# Out:
#      Pclass                                               Name     Sex   Age
# 0         3                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         3                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         3                           Allen, Mr. William Henry    male  35.0
# 5         3                                   Moran, Mr. James    male   NaN
# 6         1                            McCarthy, Mr. Timothy J    male  54.0
# 7         3                     Palsson, Master. Gosta Leonard    male   2.0
# 8         3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9         2                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10        3                    Sandstrom, Miss. Marguerite Rut  female   4.0
# ...

# %%
bunny.loc[[0,1,2],"Pclass":"Age"]
# Out:
#    Pclass                                               Name     Sex   Age
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0

# %%
bunny.loc[0:2,"Pclass":"Age"]
# Out:
#    Pclass                                               Name     Sex   Age
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0

# %%
bunny.iloc[:]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
bunny.iloc[:,1]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, dtype: int64

# %%
bunny.iloc[::-1,::-1]
# Out:
#     Embarked        Cabin      Fare            Ticket  Parch  SibSp   Age  \
# 890        Q          NaN    7.7500            370376      0      0  32.0
# 889        C         C148   30.0000            111369      0      0  26.0
# 888        S          NaN   23.4500        W./C. 6607      2      1   NaN
# 887        S          B42   30.0000            112053      0      0  19.0
# 886        S          NaN   13.0000            211536      0      0  27.0
# 885        Q          NaN   29.1250            382652      5      0  39.0
# 884        S          NaN    7.0500   SOTON/OQ 392076      0      0  25.0
# 883        S          NaN   10.5000  C.A./SOTON 34068      0      0  28.0
# 882        S          NaN   10.5167              7552      0      0  22.0
# 881        S          NaN    7.8958            349257      0      0  33.0
# 880        S          NaN   26.0000            230433      1      0  25.0
# 879        C          C50   83.1583             11767      1      0  56.0
# ...

# %%
bunny.iloc[0:4,0:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)

# %%
bunny.iloc[0:3:2,0:4]
# Out:
#    PassengerId  Survived  Pclass                     Name
# 0            1         0       3  Braund, Mr. Owen Harris
# 2            3         1       3   Heikkinen, Miss. Laina

# %%
a=[11,22,33,44,55,66]

# %%
a
# Out:
# [11, 22, 33, 44, 55, 66]

# %%
a[0]
# Out:
# 11

# %%
a[-1]
# Out:
# 66

# %%
a[:]
# Out:
# [11, 22, 33, 44, 55, 66]

# %%
len(a)
# Out:
# 6

# %%
a[:4]
# Out:
# [11, 22, 33, 44]

# %%
a[2:4]
# Out:
# [33, 44]

# %%
a[2:-1]
# Out:
# [33, 44, 55]

# %%
a[::2]
# Out:
# [11, 33, 55]

# %%
a[::4]
# Out:
# [11, 55]

# %%
a[::-1]
# Out:
# [66, 55, 44, 33, 22, 11]

# %%
bunny.iloc[0:3:2,0:4]
# Out:
#    PassengerId  Survived  Pclass                     Name
# 0            1         0       3  Braund, Mr. Owen Harris
# 2            3         1       3   Heikkinen, Miss. Laina

# %%
bunny.iloc[::1]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
bunny.iloc[::1,::2]
# Out:
#      PassengerId  Pclass     Sex  SibSp            Ticket        Cabin
# 0              1       3    male      1         A/5 21171          NaN
# 1              2       1  female      1          PC 17599          C85
# 2              3       3  female      0  STON/O2. 3101282          NaN
# 3              4       1  female      1            113803         C123
# 4              5       3    male      0            373450          NaN
# 5              6       3    male      0            330877          NaN
# 6              7       1    male      0             17463          E46
# 7              8       3    male      3            349909          NaN
# 8              9       3  female      0            347742          NaN
# 9             10       2  female      1            237736          NaN
# 10            11       3  female      1           PP 9549           G6
# 11            12       1  female      0            113783         C103
# ...

# %%
bunny.head(0)
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
bunny.keys()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
s=bunny[bunny["Embarked"]=="S"]

# %%
s
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 17            18         1       2
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 29            30         0       3
# 33            34         0       2
# 35            36         0       1
# 37            38         0       3
# ...

# %%
female=s[s["Sex"]=="female"]

# %%
female
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 10            11         1       3
# 11            12         1       1
# 14            15         0       3
# 15            16         1       2
# 18            19         0       3
# 24            25         0       3
# 25            26         1       3
# 38            39         0       3
# 40            41         0       3
# 41            42         0       2
# 49            50         0       3
# 53            54         1       2
# 56            57         1       2
# 58            59         1       2
# 66            67         1       2
# 68            69         1       3
# 71            72         0       3
# 79            80         1       3
# 84            85         1       2
# 85            86         1       3
# 88            89         1       1
# 98            99         1       2
# ...

# %%
male=s[s["Sex"]=="male"]

# %%
male
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 17            18         1       2             Williams, Mr. Charles Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# 23            24         1       1             Sloper, Mr. William Thompson
# 27            28         0       1           Fortune, Mr. Charles Alexander
# ...

# %% [markdown]
# len(male)

# %%
len(male)
# Out:
# 441

# %%
len(female)
# Out:
# 203

# %%
C=bunny[bunny["Embarked"]=="C"]

# %%
C
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# 31            32         1       1
# 34            35         0       1
# 36            37         1       3
# 39            40         1       3
# 42            43         0       3
# 43            44         1       2
# 48            49         0       3
# 52            53         1       1
# 54            55         0       1
# 57            58         0       3
# 60            61         0       3
# 64            65         0       1
# 65            66         1       3
# 73            74         0       3
# 96            97         0       1
# 97            98         1       1
# 111          112         0       3
# 114          115         0       3
# 118          119         0       1
# 122          123         0       2
# ...

# %%
len(C)
# Out:
# 168

# %%
femaleC=C[C["Sex"]=="female"]

# %%
femaleC
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 31            32         1       1
# 39            40         1       3
# 43            44         1       2
# 52            53         1       1
# 111          112         0       3
# 114          115         0       3
# 128          129         1       3
# 140          141         0       3
# 177          178         0       1
# 194          195         1       1
# 195          196         1       1
# 215          216         1       1
# 218          219         1       1
# 240          241         0       3
# 255          256         1       3
# 256          257         1       1
# 258          259         1       1
# 291          292         1       1
# 299          300         1       1
# 306          307         1       1
# 307          308         1       1
# 309          310         1       1
# ...

# %%
len(femaleC)
# Out:
# 73

# %%
totalfemale=female+femaleC

# %%
totalfemale
# Out:
#      PassengerId  Survived  Pclass Name  Sex  Age  SibSp  Parch Ticket  Fare  \
# 1            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 2            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 3            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 8            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 9            NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 10           NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 11           NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 14           NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 15           NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 18           NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# 19           NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN   NaN
# ...

# %%
len(bunny[(bunny.Embarked=="S")|(bunny.Embarked=="C")])
# Out:
# 812

# %%
True & True
# Out:
# True

# %%
5 & 6
# Out:
# 4

# %%
5 and 6
# Out:
# 6

# %%
len(bunny)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0b64c5fc0046> in <module>()
# ----> 1 len(bunny)
#
# NameError: name 'bunny' is not defined
