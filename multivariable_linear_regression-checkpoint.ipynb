# %%
import pandas as kg

# %%
bunny=kg.read_csv(r"C:\Users\STUDENT\Desktop\SonalkgML\DataSets-master\Advertising.csv")

# %%
bunny
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
x_input=bunny.iloc[:,1:4]

# %%
x_input
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# 5      8.7   48.9       75.0
# 6     57.5   32.8       23.5
# 7    120.2   19.6       11.6
# 8      8.6    2.1        1.0
# 9    199.8    2.6       21.2
# 10    66.1    5.8       24.2
# 11   214.7   24.0        4.0
# 12    23.8   35.1       65.9
# 13    97.5    7.6        7.2
# 14   204.1   32.9       46.0
# 15   195.4   47.7       52.9
# 16    67.8   36.6      114.0
# 17   281.4   39.6       55.8
# 18    69.2   20.5       18.3
# 19   147.3   23.9       19.1
# 20   218.4   27.7       53.4
# 21   237.4    5.1       23.5
# 22    13.2   15.9       49.6
# 23   228.3   16.9       26.2
# 24    62.3   12.6       18.3
# 25   262.9    3.5       19.5
# 26   142.9   29.3       12.6
# 27   240.1   16.7       22.9
# 28   248.8   27.1       22.9
# 29    70.6   16.0       40.8
# ..     ...    ...        ...
# ...

# %%
y_output=bunny.iloc[:,4]

# %%
y_output
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
# 5       7.2
# 6      11.8
# 7      13.2
# 8       4.8
# 9      10.6
# 10      8.6
# 11     17.4
# 12      9.2
# 13      9.7
# 14     19.0
# 15     22.4
# 16     12.5
# 17     24.4
# 18     11.3
# 19     14.6
# 20     18.0
# 21     12.5
# 22      5.6
# 23     15.5
# 24      9.7
# 25     12.0
# 26     15.0
# 27     15.9
# 28     18.9
# 29     10.5
#        ...
# 170     8.4
# 171    14.5
# 172     7.6
# 173    11.7
# 174    11.5
# 175    27.0
# 176    20.2
# 177    11.7
# 178    11.8
# 179    12.6
# 180    10.5
# 181    12.2
# 182     8.7
# 183    26.2
# 184    17.6
# 185    22.6
# 186    10.3
# 187    17.3
# 188    15.9
# 189     6.7
# 190    10.8
# 191     9.9
# 192     5.9
# 193    19.6
# 194    17.3
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, dtype: float64

# %%
xx_input=x_input.values.reshape(-1,3)
yy_output=y_output.values.reshape(-1,1)

# %%
X_train=xx_input[:140]
X_test=xx_input[140:]
Y_train=yy_output[:140]
Y_test=yy_output[140:]

# %%
X_test
# Out:
# array([[  73.4,   17. ,   12.9],
#        [ 193.7,   35.4,   75.6],
#        [ 220.5,   33.2,   37.9],
#        [ 104.6,    5.7,   34.4],
#        [  96.2,   14.8,   38.9],
#        [ 140.3,    1.9,    9. ],
#        [ 240.1,    7.3,    8.7],
#        [ 243.2,   49. ,   44.3],
#        [  38. ,   40.3,   11.9],
#        [  44.7,   25.8,   20.6],
#        [ 280.7,   13.9,   37. ],
#        [ 121. ,    8.4,   48.7],
#        [ 197.6,   23.3,   14.2],
#        [ 171.3,   39.7,   37.7],
#        [ 187.8,   21.1,    9.5],
#        [   4.1,   11.6,    5.7],
#        [  93.9,   43.5,   50.5],
#        [ 149.8,    1.3,   24.3],
#        [  11.7,   36.9,   45.2],
#        [ 131.7,   18.4,   34.6],
#        [ 172.5,   18.1,   30.7],
#        [  85.7,   35.8,   49.3],
#        [ 188.4,   18.1,   25.6],
#        [ 163.5,   36.8,    7.4],
#        [ 117.2,   14.7,    5.4],
#        [ 234.5,    3.4,   84.8],
#        [  17.9,   37.6,   21.6],
#        [ 206.8,    5.2,   19.4],
# ...

# %%
learner=teacher.fit(X_train,Y_train)
yp=learner.predict(X_test)

# %%
c=learner.intercept_

# %%
ya=Y_test
yplist=list(yp)
xlist=list(X_test)
yalist=list(Y_test)
mytable=kg.DataFrame({"X_test":xlist,"ya":yalist,"yp":yplist})

# %%
mytable
# Out:
#                  X_test      ya               yp
# 0    [73.4, 17.0, 12.9]  [10.9]  [9.51435440217]
# 1   [193.7, 35.4, 75.6]  [19.2]  [18.2920287655]
# 2   [220.5, 33.2, 37.9]  [20.1]  [19.2709406424]
# 3    [104.6, 5.7, 34.4]  [10.4]  [8.88723581838]
# 4    [96.2, 14.8, 38.9]  [11.4]  [10.1136170553]
# 5     [140.3, 1.9, 9.0]  [10.3]   [9.9604197209]
# 6     [240.1, 7.3, 8.7]  [13.2]  [15.6270678766]
# 7   [243.2, 49.0, 44.3]  [25.4]  [23.1587013047]
# 8    [38.0, 40.3, 11.9]  [10.9]  [12.0384503076]
# 9    [44.7, 25.8, 20.6]  [10.1]  [9.72212471318]
# 10  [280.7, 13.9, 37.0]  [16.1]  [18.6380945508]
# 11   [121.0, 8.4, 48.7]  [11.6]  [10.1009986722]
# 12  [197.6, 23.3, 14.2]  [16.6]  [16.4858961557]
# 13  [171.3, 39.7, 37.7]  [19.0]  [18.1246860868]
# 14   [187.8, 21.1, 9.5]  [15.6]  [15.6436426643]
# 15     [4.1, 11.6, 5.7]   [3.2]  [5.30523275025]
# 16   [93.9, 43.5, 50.5]  [15.3]   [15.127442315]
# 17   [149.8, 1.3, 24.3]  [10.1]  [10.2535872485]
# ...

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
error=np.sqrt(mean_squared_error(ya,yp))

# %%
error
# Out:
# 1.5993642253910214

# %%
slope=learner.coef_

# %%
slope
# Out:
# array([[ 0.04704868,  0.17968299, -0.00300557]])

# %%
slope[0,1]
# Out:
# 0.17968298889993567

# %%
tv=X_test[:,0]

# %%
tv
# Out:
# array([  73.4,  193.7,  220.5,  104.6,   96.2,  140.3,  240.1,  243.2,
#          38. ,   44.7,  280.7,  121. ,  197.6,  171.3,  187.8,    4.1,
#          93.9,  149.8,   11.7,  131.7,  172.5,   85.7,  188.4,  163.5,
#         117.2,  234.5,   17.9,  206.8,  215.4,  284.3,   50. ,  164.5,
#          19.6,  168.4,  222.4,  276.9,  248.4,  170.2,  276.7,  165.6,
#         156.6,  218.5,   56.2,  287.6,  253.8,  205. ,  139.5,  191.1,
#         286. ,   18.7,   39.5,   75.5,   17.2,  166.8,  149.7,   38.2,
#          94.2,  177. ,  283.6,  232.1])

# %%
type(tv)
# Out:
# numpy.ndarray

# %%
r=X_test[:,1]

# %%
N=X_test[:,2]

# %%
yptv=tv*slope[0,0]+c

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(tv,yptv,"r*")
plt.show()

# %%
plt.plot(tv,yptv,"r*")
plt.plot(tv,Y_test,"bo")
plt.legend(["yptv","yp"])
plt.title("Tv")
plt.show()

# %%
yp_r=r*slope[0,1]+c

# %%
plt.plot(r,yp_r,"r*")
plt.plot(r,Y_test,"bo")
plt.legend(["yp_r","yp"])
plt.title("Radio")
plt.show()

# %%
yp_n=N*slope[0,2]+c

# %%
plt.plot(N,yp_n,"r*")
plt.plot(N,Y_test,"bo")
plt.legend(["yp_n","yp"])
plt.title("newspaper")
plt.show()

# %%
learner.predict([[230.1,37.8,69.2]])
# Out:
# array([[ 20.45507554]])

# %%
plt.plot(tv,yptv,"y*")
plt.plot(r,yp_r,"r*")
plt.plot(N,yp_n,"b*")
plt.show()
