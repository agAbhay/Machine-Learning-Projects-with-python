# %%
import pandas as kg

# %%
bunny=kg.read_csv(r"C:\Users\STUDENT\Desktop\SonalkgML\DataSets-master\bmi_male_female.csv")

# %%
bunny
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# 5      Male     189     104      3
# 6      Male     147      92      5
# 7      Male     154     111      5
# 8      Male     174      90      3
# 9    Female     169     103      4
# 10     Male     195      81      2
# 11   Female     159      80      4
# 12   Female     192     101      3
# 13     Male     155      51      2
# 14     Male     191      79      2
# 15   Female     153     107      5
# 16   Female     157     110      5
# 17     Male     140     129      5
# 18     Male     144     145      5
# 19     Male     172     139      5
# 20     Male     157     110      5
# 21   Female     153     149      5
# 22   Female     169      97      4
# 23     Male     185     139      5
# 24   Female     172      67      2
# 25   Female     151      64      3
# ...

# %%
bunny.shape
# Out:
# (500, 4)

# %%
num_male=bunny[bunny["Gender"]=='Male']

# %%
num_male
# Out:
#     Gender  Height  Weight  Index
# 0     Male     174      96      4
# 1     Male     189      87      2
# 4     Male     149      61      3
# 5     Male     189     104      3
# 6     Male     147      92      5
# 7     Male     154     111      5
# 8     Male     174      90      3
# 10    Male     195      81      2
# 13    Male     155      51      2
# 14    Male     191      79      2
# 17    Male     140     129      5
# 18    Male     144     145      5
# 19    Male     172     139      5
# 20    Male     157     110      5
# 23    Male     185     139      5
# 26    Male     190      95      3
# 27    Male     187      62      1
# 29    Male     179     152      5
# 30    Male     153     121      5
# 31    Male     178      52      1
# 37    Male     144      80      4
# 42    Male     157      56      2
# 43    Male     161     118      5
# 45    Male     185      76      2
# 47    Male     181     111      4
# 48    Male     161      72      3
# ...

# %%
len(num_male)
# Out:
# 245

# %%
overw=num_male[num_male["Index"]==3]

# %%
len(overw)
# Out:
# 32

# %%
num_female=bunny[bunny["Gender"]=='Female']

# %%
overwf=num_female[num_female["Index"]==3]

# %%
len(overwf)
# Out:
# 36

# %%
index_name=kg.Series(["Extermely weak","weak","Normal","Overweight","Obesity","Extreme Obesity"])

# %%
index_name
# Out:
# 0     Extermely weak
# 1               weak
# 2             Normal
# 3         Overweight
# 4            Obesity
# 5    Extreme Obesity
# dtype: object

# %%
index_name[4]
# Out:
# 'Obesity'

# %%
#encode male.............0,Female....1
bunny.Gender[bunny.Gender=="Male"]=0
bunny.Gender[bunny.Gender=="Female"]=1
# Out:
# C:\Users\STUDENT\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\STUDENT\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
bunny
# Out:
#     Gender  Height  Weight  Index
# 0        0     174      96      4
# 1        0     189      87      2
# 2        1     185     110      4
# 3        1     195     104      3
# 4        0     149      61      3
# 5        0     189     104      3
# 6        0     147      92      5
# 7        0     154     111      5
# 8        0     174      90      3
# 9        1     169     103      4
# 10       0     195      81      2
# 11       1     159      80      4
# 12       1     192     101      3
# 13       0     155      51      2
# 14       0     191      79      2
# 15       1     153     107      5
# 16       1     157     110      5
# 17       0     140     129      5
# 18       0     144     145      5
# 19       0     172     139      5
# 20       0     157     110      5
# 21       1     153     149      5
# 22       1     169      97      4
# 23       0     185     139      5
# 24       1     172      67      2
# 25       1     151      64      3
# ...

# %%
b_input=bunny.iloc[:,0:3]

# %%
b_input
# Out:
#     Gender  Height  Weight
# 0        0     174      96
# 1        0     189      87
# 2        1     185     110
# 3        1     195     104
# 4        0     149      61
# 5        0     189     104
# 6        0     147      92
# 7        0     154     111
# 8        0     174      90
# 9        1     169     103
# 10       0     195      81
# 11       1     159      80
# 12       1     192     101
# 13       0     155      51
# 14       0     191      79
# 15       1     153     107
# 16       1     157     110
# 17       0     140     129
# 18       0     144     145
# 19       0     172     139
# 20       0     157     110
# 21       1     153     149
# 22       1     169      97
# 23       0     185     139
# 24       1     172      67
# 25       1     151      64
# 26       0     190      95
# 27       0     187      62
# 28       1     163     159
# 29       0     179     152
# ..     ...     ...     ...
# 470      0     147     142
# 471      0     154     112
# ...

# %%
#input mydata[["gender","height","weight"]]
b_target=bunny["Index"]

# %%
b_target
# Out:
# 0      4
# 1      2
# 2      4
# 3      3
# 4      3
# 5      3
# 6      5
# 7      5
# 8      3
# 9      4
# 10     2
# 11     4
# 12     3
# 13     2
# 14     2
# 15     5
# 16     5
# 17     5
# 18     5
# 19     5
# 20     5
# 21     5
# 22     4
# 23     5
# 24     2
# 25     3
# 26     3
# 27     1
# 28     5
# 29     5
#       ..
# 470    5
# 471    5
# 472    2
# 473    5
# 474    3
# 475    4
# 476    5
# 477    2
# 478    2
# 479    5
# 480    5
# 481    4
# 482    5
# 483    4
# 484    4
# 485    4
# 486    5
# 487    2
# 488    4
# 489    5
# 490    2
# 491    5
# 492    0
# 493    1
# 494    5
# 495    5
# 496    4
# 497    5
# 498    5
# 499    5
# Name: Index, dtype: int64

# %%
b_input.shape
# Out:
# (500, 3)

# %%
import numpy as np

# %%
b=b_input.values.reshape(500,3)

# %%
b
# Out:
# array([[0, 174, 96],
#        [0, 189, 87],
#        [1, 185, 110],
#        ...,
#        [1, 141, 136],
#        [0, 150, 95],
#        [0, 173, 131]], dtype=object)

# %%
s=b_target.values.reshape(-1,1)

# %%
s
# Out:
# array([[4],
#        [2],
#        [4],
#        [3],
#        [3],
#        [3],
#        [5],
#        [5],
#        [3],
#        [4],
#        [2],
#        [4],
#        [3],
#        [2],
#        [2],
#        [5],
#        [5],
#        [5],
#        [5],
#        [5],
#        [5],
#        [5],
#        [4],
#        [5],
#        [2],
#        [3],
#        [3],
#        [1],
#        [5],
#        [5],
#        [5],
#        [1],
#        [1],
#        [5],
#        [5],
#        [4],
#        [3],
#        [4],
#        [5],
#        [2],
#        [4],
#        [5],
#        [2],
#        [5],
#        [4],
#        [2],
#        [4],
#        [4],
#        [3],
#        [5],
#        [5],
#        [1],
#        [5],
#        [4],
#        [4],
#        [3],
#        [4],
#        [5],
#        [3],
#        [5],
#        [0],
#        [5],
#        [0],
#        [2],
#        [5],
#        [5],
#        [4],
#        [2],
#        [4],
#        [4],
#        [2],
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
X_train=b[:350]
X_test=b[350:]
Y_train=s[:350]
Y_test=s[350:]

# %%
teacher=KNeighborsClassifier()

# %%
learner=teacher.fit(X_train,Y_train)
# Out:
# C:\Users\STUDENT\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   if __name__ == '__main__':

# %%
p=learner.predict([[1,170,53]])

# %%
index_name[p]
# Out:
# 2    Normal
# dtype: object

# %%
p=learner.predict([[1,160,54]])

# %%
index_name[p]
# Out:
# 2    Normal
# dtype: object

# %%
p=learner.predict([[0,170,67]])

# %%
index_name[p]
# Out:
# 2    Normal
# dtype: object

# %%
Ya=Y_test
Yp=learner.predict(X_test)

# %%
Yalist=list(Ya)
Yplist=list(Yp)

# %%
table=kg.DataFrame({"Ya":Yalist,"Yp":Yplist})

# %%
table
# Out:
#       Ya  Yp
# 0    [2]   3
# 1    [2]   2
# 2    [2]   2
# 3    [5]   5
# 4    [0]   0
# 5    [3]   3
# 6    [4]   4
# 7    [5]   5
# 8    [1]   1
# 9    [4]   5
# 10   [1]   1
# 11   [4]   5
# 12   [5]   5
# 13   [4]   4
# 14   [5]   5
# 15   [5]   4
# 16   [3]   3
# 17   [4]   4
# 18   [5]   5
# 19   [4]   4
# 20   [3]   3
# 21   [5]   5
# 22   [1]   1
# 23   [2]   2
# 24   [4]   4
# 25   [5]   5
# 26   [5]   5
# 27   [5]   5
# 28   [5]   4
# 29   [3]   3
# ..   ...  ..
# 120  [5]   5
# 121  [5]   5
# 122  [2]   2
# 123  [5]   4
# 124  [3]   3
# 125  [4]   4
# 126  [5]   5
# 127  [2]   2
# 128  [2]   2
# 129  [5]   5
# 130  [5]   5
# 131  [4]   4
# 132  [5]   5
# 133  [4]   5
# 134  [4]   4
# 135  [4]   4
# 136  [5]   5
# 137  [2]   2
# 138  [4]   4
# 139  [5]   5
# 140  [2]   2
# 141  [5]   5
# 142  [0]   0
# 143  [1]   2
# 144  [5]   5
# 145  [5]   5
# 146  [4]   4
# 147  [5]   5
# 148  [5]   5
# 149  [5]   5
#
# [150 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

# %%
acc=accuracy_score(Ya,Yp)*100

# %%
acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b2739c798308> in <module>()
# ----> 1 acc
#
# NameError: name 'acc' is not defined

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-72fbbcfe2587> in <module>()
# ----> 1 import cv2
#
# C:\Users\AbhayGupta\Anaconda3\lib\site-packages\cv2\__init__.py in <module>()
#       1 import importlib
#       2
# ----> 3 from .cv2 import *
#       4 from .data import *
#       5
#
# ImportError: DLL load failed: The specified module could not be found.
