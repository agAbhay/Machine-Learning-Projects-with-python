# %%
import seaborn as sb
import pandas as kg
import numpy as np
import matplotlib.pyplot as ml
# %matplotlib inline 
#only used in python to avoid use of plt.show()
#dark grid white grid dark and wide and 
sb.set_style("whitegrid")

# %%
sb.__version__
# Out:
# '0.7.1'

# %%
kg.__version__
# Out:
# '0.19.2'

# %%
np.__version__
# Out:
# '1.11.3'

# %%
ml.__version__
# Out:
# '2.0.0'

# %%
bunny=kg.read_excel(r"C:/Users/STUDENT/Desktop/SonalkgML/Pokemon_Data.xlsx")

# %%
bunny
# Out:
#        #        Name    Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur     Grass   Poison    318   45      49       49       65
# 1      2     Ivysaur     Grass   Poison    405   60      62       63       80
# 2      3    Venusaur     Grass   Poison    525   80      82       83      100
# 3      4  Charmander      Fire      NaN    309   39      52       43       60
# 4      5  Charmeleon      Fire      NaN    405   58      64       58       80
# 5      6   Charizard      Fire   Flying    534   78      84       78      109
# 6      7    Squirtle     Water      NaN    314   44      48       65       50
# 7      8   Wartortle     Water      NaN    405   59      63       80       65
# 8      9   Blastoise     Water      NaN    530   79      83      100       85
# 9     10    Caterpie       Bug      NaN    195   45      30       35       20
# 10    11     Metapod       Bug      NaN    205   50      20       55       25
# ...

# %%
sb.lmplot(x='Attack',y='Defense',data=bunny,fit_reg=False)

# %%
sb.lmplot(x='Attack',y='Defense',data=bunny)

# %%
sb.lmplot(x='Attack',y='Defense',data=bunny,fit_reg=False,scatter_kws={"color":"red"})

# %%
sb.lmplot(x='Attack',y='Defense',data=bunny,fit_reg=False,hue="Stage",markers=["*","^","<"])

# %%
sb.set_style("ticks")

# %%
sb.lmplot(x='Attack',y='Defense',data=bunny,fit_reg=False,scatter_kws={"color":"red"})

# %%
sb.countplot(x="Type 1",data=bunny)
ml.xticks(rotation=45)
ml.show()

# %%
ml.xticks(rotation=45)
ml.show()

# %%
sb.countplot(x="Type 1",data=bunny,hue='Type 2')
ml.xticks(rotation=45)
ml.show()

# %%
sb.countplot(y="Type 1",data=bunny,hue='Type 2')
ml.xticks(rotation=45)
ml.show()
