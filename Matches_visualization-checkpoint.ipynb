# %%
import pandas as kg
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
bunny=kg.read_csv(r"C:\Users\STUDENT\Desktop\SonalkgML\matches.csv")

# %%
bunny
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
bunny.shape
# Out:
# (636, 18)

# %%
num_s=bunny["season"]

# %%
len(np.unique(num_s))
# Out:
# 10

# %%
bunny["win_by_runs"].max()
# Out:
# 146

# %%
maxteam=bunny[bunny['win_by_runs']==146]

# %%
maxteam
# Out:
#     id  season   city        date           team1             team2  \
# 43  44    2017  Delhi  2017-05-06  Mumbai Indians  Delhi Daredevils
#
#          toss_winner toss_decision  result  dl_applied          winner  \
# 43  Delhi Daredevils         field  normal           0  Mumbai Indians
#
#     win_by_runs  win_by_wickets player_of_match             venue  \
# 43          146               0     LMP Simmons  Feroz Shah Kotla
#
#         umpire1    umpire2  umpire3
# 43  Nitin Menon  CK Nandan      NaN

# %%
bunny['win_by_runs'].idxmax()
# Out:
# 43

# %%
bunny.iloc[bunny.win_by_runs.idxmax()]['winner']
# Out:
# 'Mumbai Indians'

# %%
bunny.iloc[bunny.win_by_wickets.idxmax()]['winner']
# Out:
# 'Kolkata Knight Riders'

# %%
bunny.iloc[bunny.win_by_wickets.idxmin()]['winner']
# Out:
# 'Sunrisers Hyderabad'

# %%
bunny[bunny['win_by_runs'].ge(1)].shape
# Out:
# (287, 18)

# %%
bunny.iloc[bunny[bunny['win_by_runs'].ge(1)].win_by_runs.idxmin()]['winner']
# Out:
# 'Mumbai Indians'

# %%
bunny.iloc[bunny[bunny['win_by_wickets'].ge(1)].win_by_wickets.idxmin()]['winner']
# Out:
# 'Kolkata Knight Riders'

# %%
sb.countplot(x="season",data=bunny)

# %%
sb.countplot(x="player_of_match",data=bunny)
plt.xticks(rotation=45)
plt.show()

# %%
manofmatch=bunny.player_of_match

# %%
manofmatch.iloc[-1]
# Out:
# 'BCJ Cutting'

# %%
len(manofmatch.unique())
# Out:
# 202

# %%
bunny["player_of_match"].value_counts()[:10]
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# SK Raina          14
# RG Sharma         14
# G Gambhir         13
# MS Dhoni          13
# MEK Hussey        12
# AM Rahane         12
# Name: player_of_match, dtype: int64

# %%
mof=bunny["player_of_match"].value_counts()[:10]

# %%
sb.barplot(x=mof.index,y=mof.values)
plt.xticks(rotation=45)
plt.show()
