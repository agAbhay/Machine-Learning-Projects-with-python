# %%
import pandas as pd

# %%
bunny=pd.read_csv(r"E:\Datasets\DataSets-master\DataSets-master\Titanic_Data.csv")

# %%
bunny
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
import seaborn  as sb

# %%
from matplotlib import pyplot as plt

# %%
bunny.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
sb.lmplot(x="Age",y="Survived",data=bunny)
plt.show()

# %%
sb.lmplot(x="Age",y="Survived",hue='Pclass',data=bunny,markers=['o','*',">"])
plt.show()

# %%
sb.lmplot(x="Age",y="Survived",hue='Pclass',col='Pclass',row='Sex',data=bunny,markers=['o','*',">"])
plt.show()

# %%
bunny1=pd.read_csv(r"E:\Datasets\DataSets-master\DataSets-master\births.csv")

# %%
bunny1
# Out:
#        Unnamed: 0  year  month   day gender  births
# 0               0  1969      1     1      F    4046
# 1               1  1969      1     1      M    4440
# 2               2  1969      1     2      F    4454
# 3               3  1969      1     2      M    4548
# 4               4  1969      1     3      F    4548
# 5               5  1969      1     3      M    4994
# 6               6  1969      1     4      F    4440
# 7               7  1969      1     4      M    4520
# 8               8  1969      1     5      F    4192
# 9               9  1969      1     5      M    4198
# 10             10  1969      1     6      F    4710
# 11             11  1969      1     6      M    4850
# 12             12  1969      1     7      F    4646
# 13             13  1969      1     7      M    5092
# 14             14  1969      1     8      F    4800
# 15             15  1969      1     8      M    4934
# 16             16  1969      1     9      F    4592
# ...

# %%
decade=bunny1.iloc[0:bunny1[bunny1["year"]<=1979],:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-1f695eeed2f3> in <module>()
# ----> 1 decade=bunny1.iloc[0:bunny1[bunny1["year"]<=1979],:]
#
# C:\Users\Abhay Gupta\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1308
#    1309         if type(key) is tuple:
# -> 1310             return self._getitem_tuple(key)
#    1311         else:
#    1312             return self._getitem_axis(key, axis=0)
#
# C:\Users\Abhay Gupta\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1574                 continue
#    1575
# -> 1576             retval = getattr(retval, self.name)._getitem_axis(key, axis=axis)
#    1577
#    1578             # if the dim was reduced, then pass a lower-dim the next time
#
# ...

# %%
sb.countplot(x="births",y='gender',data=bunny1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-ad61fab3284a> in <module>()
# ----> 1 sb.countplot(x="births",y='gender',data=bunny1)
#       2 plt.show()
#
# C:\Users\Abhay Gupta\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, ax, **kwargs)
#    3249         y = x
#    3250     elif x is not None and y is not None:
# -> 3251         raise TypeError("Cannot pass values for both `x` and `y`")
#    3252     else:
#    3253         raise TypeError("Must pass values for either `x` or `y`")
#
# TypeError: Cannot pass values for both `x` and `y`
