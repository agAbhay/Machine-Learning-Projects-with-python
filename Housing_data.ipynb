# %%
import pandas as pd

# %%
bunny=pd.read_csv(r"C:\Users\Abhay Gupta\Downloads\Compressed\DataSets-master\DataSets-master\Housing_Data.csv")

# %%
bunny
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0             1   42000.0     5850         3        1        2      yes
# 1             2   38500.0     4000         2        1        1      yes
# 2             3   49500.0     3060         3        1        1      yes
# 3             4   60500.0     6650         3        1        2      yes
# 4             5   61000.0     6360         2        1        1      yes
# 5             6   66000.0     4160         3        1        1      yes
# 6             7   66000.0     3880         3        2        2      yes
# 7             8   69000.0     4160         3        1        3      yes
# 8             9   83800.0     4800         3        1        1      yes
# 9            10   88500.0     5500         3        2        4      yes
# 10           11   90000.0     7200         3        2        1      yes
# 11           12   30500.0     3000         2        1        1       no
# ...

# %%
lotsize=bunny.iloc[:,2:3]

# %%
lotsize
# Out:
#      lotsize
# 0       5850
# 1       4000
# 2       3060
# 3       6650
# 4       6360
# 5       4160
# 6       3880
# 7       4160
# 8       4800
# 9       5500
# 10      7200
# 11      3000
# 12      1700
# 13      2880
# 14      3600
# 15      3185
# 16      3300
# 17      5200
# 18      3450
# 19      3986
# 20      4785
# 21      4510
# 22      4000
# 23      3934
# 24      4960
# 25      3000
# 26      3800
# 27      4960
# 28      3000
# 29      4500
# ..       ...
# 516     6000
# 517     6000
# 518     6240
# 519     6000
# 520     7680
# 521     6000
# 522     6000
# 523     6000
# 524     6000
# 525     7475
# 526     5150
# 527     6325
# 528     6000
# 529     6000
# 530     6000
# 531     7000
# 532    12900
# 533     7686
# 534     5000
# 535     5800
# 536     6000
# 537     4800
# 538     6500
# 539     7320
# 540     6525
# 541     4800
# 542     6000
# 543     6000
# 544     6000
# 545     6000
#
# [546 rows x 1 columns]

# %%
price=bunny.iloc[:,1:2]

# %%
price
# Out:
#         price
# 0     42000.0
# 1     38500.0
# 2     49500.0
# 3     60500.0
# 4     61000.0
# 5     66000.0
# 6     66000.0
# 7     69000.0
# 8     83800.0
# 9     88500.0
# 10    90000.0
# 11    30500.0
# 12    27000.0
# 13    36000.0
# 14    37000.0
# 15    37900.0
# 16    40500.0
# 17    40750.0
# 18    45000.0
# 19    45000.0
# 20    48500.0
# 21    65900.0
# 22    37900.0
# 23    38000.0
# 24    42000.0
# 25    42300.0
# 26    43500.0
# 27    44000.0
# 28    44500.0
# 29    44900.0
# ..        ...
# 516   95000.0
# 517   96500.0
# 518  101000.0
# 519  102000.0
# 520  103000.0
# 521  105000.0
# 522  108000.0
# 523  110000.0
# 524  113000.0
# 525  120000.0
# 526  105000.0
# 527  106000.0
# 528  107500.0
# 529  108000.0
# 530  113750.0
# 531  120000.0
# 532   70000.0
# 533   71000.0
# 534   82000.0
# 535   82000.0
# 536   82500.0
# 537   83000.0
# 538   84000.0
# 539   85000.0
# 540   85000.0
# 541   91500.0
# 542   94000.0
# 543  103000.0
# 544  105000.0
# 545  105000.0
#
# ...

# %%
import numpy as np

# %%
x_train=lotsize["lotsize"]
y_train=price["price"]

# %%
x_input=x_train.values.reshape(-1,1)
y_out=y_train.values.reshape(-1,1)

# %%
type(x_input)
# Out:
# numpy.ndarray

# %%
#split
xx_train=x_input[:500]
xx_test=x_input[500:]
yy_train=y_out[:500]
yy_test=y_out[500:]

# %%
xx_train.shape
# Out:
# (500, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
teacher=LinearRegression()

# %%
learner=teacher.fit(xx_train,yy_train)

# %%
learner.predict([[5000]])
# Out:
# array([[ 66080.27694774]])

# %%
#testing 
yp=learner.predict(xx_test)

# %%
ya=yy_test
yplist=list(yp)
xlist=list(xx_test)
yalist=list(yy_test)
mytable=pd.DataFrame({"xx_test":xlist,"ya":yalist,"yp":yplist})

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
error=np.sqrt(mean_squared_error(ya,yp))

# %%
error
# Out:
# 24492.997647654309

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(xx_test,yy_test,"r*")
plt.plot(xx_test,yp,"bo")
plt.xlabel("xx_test")
plt.ylabel("yy_test")
plt.legend(["Ya","Yp"])
plt.title("Price of the lotsize")
plt.show()

# %%
bedrooms=bunny[bunny["bedrooms"]==3]

# %%
bedrooms
# Out:
#      Unnamed: 0     price  lotsize  bedrooms  bathrms  stories driveway  \
# 0             1   42000.0     5850         3        1        2      yes
# 2             3   49500.0     3060         3        1        1      yes
# 3             4   60500.0     6650         3        1        2      yes
# 5             6   66000.0     4160         3        1        1      yes
# 6             7   66000.0     3880         3        2        2      yes
# 7             8   69000.0     4160         3        1        3      yes
# 8             9   83800.0     4800         3        1        1      yes
# 9            10   88500.0     5500         3        2        4      yes
# 10           11   90000.0     7200         3        2        1      yes
# 12           13   27000.0     1700         3        1        2      yes
# 13           14   36000.0     2880         3        1        1       no
# 16           17   40500.0     3300         3        1        2       no
# ...

# %%
len(bedrooms)
# Out:
# 301

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
