# %%
import pandas as pd

# %%
ro_titanic=pd.read_csv(r"C:\Users\STUDENT\Desktop\SonalkgML\DataSets-master\Titanic_Data.csv")

# %%
ro_titanic.shape
# Out:
# (891, 12)

# %%
ro_titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
num_female=ro_titanic[ro_titanic["Sex"]=="female"]

# %%
len(num_female)
# Out:
# 314

# %%
num_male=ro_titanic[ro_titanic["Sex"]=="male"]

# %%
num_male
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 17            18         1       2             Williams, Mr. Charles Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# ...

# %%
len(num_male)
# Out:
# 577

# %%
spe_female=num_female[num_female["Age"]>=22]

# %%
spe_female
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 11            12         1       1
# 15            16         1       2
# 18            19         0       3
# 25            26         1       3
# 40            41         0       3
# 41            42         0       2
# 52            53         1       1
# 53            54         1       2
# 61            62         1       1
# 66            67         1       2
# 79            80         1       3
# 85            86         1       3
# 88            89         1       1
# 98            99         1       2
# 100          101         0       3
# 123          124         1       2
# 132          133         0       3
# 133          134         1       2
# 141          142         1       3
# 142          143         1       3
# 151          152         1       1
# ...

# %%
len(spe_female)
# Out:
# 177

# %%
sur=spe_female[spe_female["Survived"]==1]

# %%
len(sur)
# Out:
# 140
